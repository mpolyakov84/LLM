# %% [markdown]
# # Building Random and Average BaseLine

# %%
from  evaluation import  evaluate_model
from datasets import load_dataset
import random

# %%
def random_rectangle(img='Test'):
    """
    Create a random rectangle in the image 
    :param img: 
    :return: normalized coordinates for rectangle
    """
    
    x_center = random.random()
    y_center = random.random()
    width = random.random()*(min(x_center, 1 - x_center))*2
    height = random.random()*(min(y_center, 1 - y_center))*2
    return {'x_center': x_center, 'y_center': y_center, 'width': width, 'height': height}

# %%
path = '../lite_dataset'
dataset = load_dataset("imagefolder",data_dir=path, streaming=True)
# Out:
# Resolving data files:   0%|          | 0/402 [00:00<?, ?it/s]

# %%
evaluate_model(random_rectangle,dataset)
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# # Average BaseLine

# %%
dataset = load_dataset("imagefolder",data_dir=path)
# Out:
# Resolving data files:   0%|          | 0/402 [00:00<?, ?it/s]

# %%
x_mean = sum(dataset['test']['x_center'])/len(dataset['test']['x_center'])
y_mean = sum(dataset['test']['y_center'])/len(dataset['test']['y_center'])
width_mean = sum(dataset['test']['width'])/len(dataset['test']['width'])
height_mean = sum(dataset['test']['height'])/len(dataset['test']['height'])
print(x_mean,y_mean,width_mean,height_mean)
# Out:
# 0.504757590839826 0.48438624591557977 0.41636090333714776 0.2667178824679356

# %%
def average_value(img='Test'):
    return {'x_center': x_mean, 'y_center': y_mean, 'width': width_mean, 'height': height_mean}

# %%
average_value()
# Out:
# {'x_center': 0.504757590839826,
#  'y_center': 0.48438624591557977,
#  'width': 0.41636090333714776,
#  'height': 0.2667178824679356}

# %%
evaluate_model(average_value,dataset)
# Out:
#   0%|          | 0/328 [00:00<?, ?it/s]
